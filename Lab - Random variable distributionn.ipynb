# %% [markdown]
# # Lab - Random variable distributionn

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
from sklearn.preprocessing import OneHotEncoder,StandardScaler,MinMaxScaler
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Instructions

# %% [markdown]
# **1.Get the numerical variables from our dataset.**

# %%
df_data=pd.read_csv(r"files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv")

# %%
df_data
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  \
# ...

# %%
df_data.columns = df_data.columns.str.lower().str.replace(' ','_')

df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   object
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
# ...

# %%
df_numeric=df_data.select_dtypes(include=np.number)
df_numeric.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %% [markdown]
# **2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.**

# %%
num_cols=list(df_numeric.columns)

# %%
for col in num_cols:
    sb.displot(df_numeric[col], kind="kde",fill=True)

# %%
for col in num_cols:
    sb.displot(df_numeric[col])

# %% [markdown]
# * "customer_lifetime_value" fits a right-skewed distribution, while "months_since_last_policy_inception" fit a distribution similar to a normal one.

# %% [markdown]
# **3.Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.**

# %% [markdown]
# ### StandardScaler

# %%
scaler=StandardScaler()

# %%
scaled=scaler.fit_transform(df_numeric)

# %%
df_scaled=pd.DataFrame(scaled,columns=list(df_numeric.columns))
df_scaled
# Out:
#       customer_lifetime_value    income  monthly_premium_auto  \
# 0                   -0.762878  0.612827             -0.703925
# 1                   -0.149245 -1.239617              0.022691
# 2                    0.710636  0.365710              0.429596
# 3                   -0.052263 -1.239617              0.371467
# 4                   -0.755575  0.203390             -0.587666
# ...                       ...       ...                   ...
# 9129                 2.241590  1.128558             -0.587666
# 9130                -0.714411 -0.528450             -0.413278
# 9131                 0.023135 -1.239617             -0.238891
# 9132                -0.069935 -0.517356              0.080820
# 9133                -0.784955 -1.239617             -0.471408
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                    1.678099                      -1.543287
# 1                   -0.208186                      -0.217334
# ...

# %%
for col in num_cols:
    sb.displot(df_scaled[col])

# %% [markdown]
# ### Logarithmic transformation

# %%
def log_transform(x):
    if np.isfinite(x) and x!=0: # If the value is finite and != 0...
        return np.log(x)
    else:
        return 0 # We are returning NaNs so that we can replace them later

# %%
df_num_log = df_numeric.applymap(log_transform)
df_num_log.head()
# Out:
#    customer_lifetime_value     income  monthly_premium_auto  \
# 0                 7.924260  10.937988              4.234107
# 1                 8.850738   0.000000              4.543295
# 2                 9.464008  10.794809              4.682131
# 3                 8.941920   0.000000              4.663439
# 4                 7.942253  10.688211              4.290459
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                 3.465736                       1.609438
# 1                 2.564949                       3.737670
# 2                 2.890372                       3.637586
# 3                 2.890372                       4.174387
# 4                 2.484907                       3.784190
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                        0.0            0.000000            5.952753
# 1                        0.0            2.079442            7.031268
# ...

# %%
for col in num_cols:
    sb.displot(df_num_log[col])

# %% [markdown]
# With the logarithmic transformation, the "total_claim_amount" turns into a more normalized distribution. The same happens with the "customer_lifetime_value" variable, which after the transformation has a mucho more normal distribution.

# %% [markdown]
# ### MinMaxScaler

# %%
min_max_scaler=MinMaxScaler()

# %%
min_max_scaled=min_max_scaler.fit_transform(df_numeric)

# %%
df_min_max_scaled=pd.DataFrame(min_max_scaled,columns=list(df_numeric.columns))
df_min_max_scaled
# Out:
#       customer_lifetime_value    income  monthly_premium_auto  \
# 0                    0.010629  0.562847              0.033755
# 1                    0.062406  0.000000              0.139241
# 2                    0.134960  0.487763              0.198312
# 3                    0.070589  0.000000              0.189873
# 4                    0.011245  0.438443              0.050633
# ...                       ...       ...                   ...
# 9129                 0.264137  0.719547              0.050633
# 9130                 0.014719  0.216081              0.075949
# 9131                 0.076951  0.000000              0.101266
# 9132                 0.069098  0.219452              0.147679
# 9133                 0.008766  0.000000              0.067511
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                    0.914286                       0.050505
# 1                    0.371429                       0.424242
# ...

# %%
for min_max_col in num_cols:
    sb.displot(df_min_max_scaled[min_max_col])

# %% [markdown]
# * By using the MinMaxScaler, we do not appreciate substantial changes comparing to the plots distribution in the original df_numerical dataframe (the non scaled one).
